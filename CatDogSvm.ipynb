# %%
# !pip install opencv-python scikit-learn numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/40.2 MB 6.5 MB/s eta 0:00:07
#    - -------------------------------------- 1.0/40.2 MB 6.5 MB/s eta 0:00:07
#    -- ------------------------------------- 2.9/40.2 MB 4.5 MB/s eta 0:00:09
#    --- ------------------------------------ 3.4/40.2 MB 3.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.5/40.2 MB 4.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/40.2 MB 4.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/40.2 MB 3.7 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.8/40.2 MB 3.5 MB/s eta 0:00:10
#    ------ --------------------------------- 6.8/40.2 MB 3.5 MB/s eta 0:00:10
#    ------- -------------------------------- 7.6/40.2 MB 3.5 MB/s eta 0:00:10
# ...

# %%
import os
import cv2
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
data = []
labels = []

cat_path = "PetImages/Cat"
dog_path = "PetImages/Dog"

# %%
for img in os.listdir(cat_path)[:500]:
    try:
        image = cv2.imread(os.path.join(cat_path, img))
        image = cv2.resize(image, (64,64))
        data.append(image.flatten())
        labels.append(0)
    except:
        pass

print("Cat images loaded")
# Out:
# Cat images loaded

# %%
for img in os.listdir(dog_path)[:500]:
    try:
        image = cv2.imread(os.path.join(dog_path, img))
        image = cv2.resize(image, (64,64))
        data.append(image.flatten())
        labels.append(1)
    except:
        pass

print("Dog images loaded")
# Out:
# Dog images loaded

# %%
data = np.array(data)
labels = np.array(labels)

print(data.shape)
print(labels.shape)
# Out:
# (999, 12288)
# (999,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data,
    labels,
    test_size=0.2,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (799, 12288)
# (200, 12288)

# %%
model = SVC(kernel='linear')

model.fit(X_train, y_train)

print("Training Completed")
# Out:
# Training Completed

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy =", accuracy)
# Out:
# Accuracy = 0.54

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.52        94
#            1       0.57      0.56      0.56       106
#
#     accuracy                           0.54       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.54      0.54      0.54       200

# %%
import joblib

joblib.dump(model, "cat_dog_svm.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully
